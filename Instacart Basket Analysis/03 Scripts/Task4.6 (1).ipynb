# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define a dictionary containing January 2020 data
data1 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'purchased_meat':[0, 13, 3, 4],
    'purchased_alcohol':[1, 2, 10, 0],
    'purchased_snacks':[10, 5, 1, 7]}

# %%
# Define a dictionary containing February 2020 data
data2 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Feb-20', 'Feb-20', 'Feb-20', 'Feb-20'],
    'purchased_meat':[0, 10, 5, 3],
    'purchased_alcohol':[2, 4, 14, 0],
    'purchased_snacks':[15, 3, 2, 6]}

# %%
#Convert the dictionary into dataframe
df = pd.DataFrame(data1,index=[0, 1, 2, 3])
df_1 = pd.DataFrame(data2,index=[0, 1, 2, 3])

# %%
df
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7

# %% [markdown]
# #The df dataframe is your January 2020 data

# %%
df_1
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# #he df dataframe is your February2020 data

# %%
frames = [df, df_1]

# %%
df_concat = pd.concat(frames)

# %%
df_prods= pd.read_csv(r'C:\\Users\\Admin\\Desktop\\Project1\\products.csv', index_col = False)

# %%
df_prods_clean = df_prods[df_prods['product_name'].isnull() == False]

# %%
df_dups = df_prods_clean[df_prods_clean.duplicated()]
df_dups
# Out:
#        product_id                                       product_name  \
# 462           462                  Fiber 4g Gummy Dietary Supplement
# 18459       18458                                         Ranger IPA
# 26810       26808               Black House Coffee Roasty Stout Beer
# 35309       35306  Gluten Free Organic Peanut Butter & Chocolate ...
# 35495       35491                            Adore Forever Body Wash
#
#        aisle_id  department_id  prices
# 462          70             11     4.8
# 18459        27              5     9.2
# 26810        27              5    13.4
# 35309       121             14     6.8
# 35495       127             11     9.9

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %% [markdown]
# #PlacE two dataframes side by side

# %%
df_concat = pd.concat(frames, axis = 1)

# %%
df_concat
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
df_appended = df.append(df_1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12140\2376842033.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_appended = df.append(df_1)

# %%
df_appended
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
# 0        6732  Feb-20               0                  2                15
# 1         767  Feb-20              10                  4                 3
# 2         890  Feb-20               5                 14                 2
# 3         635  Feb-20               3                  0                 6

# %%
# Create data with different columns from df
data3 = {'customer_id':['6732', '767', '890', '635'],
    'month':['Jan-20', 'Jan-20', 'Jan-20', 'Jan-20'],
    'days_purchased_on':[0, 13, 3, 4]}

# %%
# Convert to dataframe
df_2 = pd.DataFrame(data3,index=[0, 1, 2, 3])

# %%
df_2
# Out:
#   customer_id   month  days_purchased_on
# 0        6732  Jan-20                  0
# 1         767  Jan-20                 13
# 2         890  Jan-20                  3
# 3         635  Jan-20                  4

# %%
df_append_test = df.append(df_2)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_252\2564146318.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append_test = df.append(df_2)

# %%
df_append_test
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20             0.0                1.0              10.0
# 1         767  Jan-20            13.0                2.0               5.0
# 2         890  Jan-20             3.0               10.0               1.0
# 3         635  Jan-20             4.0                0.0               7.0
# 0        6732  Jan-20             NaN                NaN               NaN
# 1         767  Jan-20             NaN                NaN               NaN
# 2         890  Jan-20             NaN                NaN               NaN
# 3         635  Jan-20             NaN                NaN               NaN
#
#    days_purchased_on
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 0                0.0
# 1               13.0
# 2                3.0
# 3                4.0

# %%
df_merged = df.merge(df_2, on = 'customer_id')

# %%
df_merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_252\3649133032.py in <module>
# ----> 1 df_merged
#
# NameError: name 'df_merged' is not defined

# %%
df_merge=df.merge(df_2, on = ['customer_id', 'month'])

# %%
df_merge
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on
# 0                  0
# 1                 13
# 2                  3
# 3                  4

# %%
df_merged = df.merge(df_2, on = ['customer_id', 'month'], indicator = True)

# %%
df_merged
# Out:
#   customer_id   month  purchased_meat  purchased_alcohol  purchased_snacks  \
# 0        6732  Jan-20               0                  1                10
# 1         767  Jan-20              13                  2                 5
# 2         890  Jan-20               3                 10                 1
# 3         635  Jan-20               4                  0                 7
#
#    days_purchased_on _merge
# 0                  0   both
# 1                 13   both
# 2                  3   both
# 3                  4   both

# %%
df_merged['_merge'].value_counts()
# Out:
# both          4
# left_only     0
# right_only    0
# Name: _merge, dtype: int64

# %%
path=r'C:\\Users\\Admin\\05-01-2023 Instacart Basket Analysis'

# %% [markdown]
# #1.If you haven’t merged your prepared Instacart orders data with the new orders_products_prior dataframe per the instructions in his Exercise, do so now.

# %%
df_ord_prod_prior= pd.read_csv(r'C:\Users\Admin\Desktop\Project1\order_products__prior.csv', index_col = False)

# %%
df_ord_prod_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ord_prod_prior.shape
# Out:
# (32434489, 4)

# %%
df= pd.read_csv(r'C:\Users\Admin\Desktop\Project1\orders.csv', index_col = False)

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
    df_merged_large = df_ords_prod_combined.merge(df_prods, on = 'product_id', indicator = 'exists')

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists
# ...

# %% [markdown]
# #2.Export the merged file in pickle format as “orders_products_combined.pkl”.

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# #3.Importing order products combined

# %%
df_ords_prod_combined= pd.read_csv(r'C:\Users\Admin\Desktop\Project1\orders_products_combined.csv', index_col=0)

# %% [markdown]
# #4.Checking the Data Frame (should be same as the one exported)

# %%
df_ords_prod_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %% [markdown]
# #5.Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
roducts_combined= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods=pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col=False)

# %%
df_merged_large.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.csv'))

# %%
df_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
df_ords_prod_combined.shape
# Out:
# (3189726, 11)

# %% [markdown]
# #Import products.csv

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %%
df_ords_prod_combined.head()

# %%
df_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
df_ords_prod_combined= df_ords_prod_combined.drop(columns = ['_merge'])
    "df_orders_products_merged.head()"

# %%
df_ords_prod_combined.shape
# Out:
# (3189726, 10)

# %%
df_merged_large=df_ords_prod_combined.merge(df_prods, on='order_id', indicator=True)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id_x eval_set_x  order_number_x  order_dow  \
# 0   2539329          1      prior               1          2
# 1   2539329          1      prior               1          2
# 2   2539329          1      prior               1          2
# 3   2539329          1      prior               1          2
# 4   2539329          1      prior               1          2
#
#    order_hour_of_day_x  days_since_prior_order_x  product_id  \
# 0                    8                       NaN         196
# 1                    8                       NaN       14084
# 2                    8                       NaN       12427
# 3                    8                       NaN       26088
# 4                    8                       NaN       26405
#
#    add_to_cart_order  reordered  ...  days_since_prior_order_y  _merge  \
# 0                  1          0  ...                     999.0    both
# 1                  2          0  ...                     999.0    both
# ...

# %% [markdown]
# #Confirm the results of the merge using the merge flag.

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          1533067
# left_only           0
# right_only          0
# Name: _merge, dtype: int64

# %% [markdown]
# #Checking shape of merged data frame

# %%
df_merged_large.shape
# Out:
# (1533067, 19)

# %%
#Export data to pkl

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merge.pkl'))

# %%
path=r'C:\\Users\\Admin\\05-01-2023 Instacart Basket Analysis'

# %%
df_orders_products = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)
df_prods.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             1           1   2398795        1    prior             2
# 2             2           2    473747        1    prior             3
# 3             3           3   2254736        1    prior             4
# 4             4           4    431534        1    prior             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0

# %%
df_orders_products.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices exists
# ...

# %%
df_orders_products.shape
# Out:
# (1533067, 19)

# %%
df_orders_products_merged = df_orders_products.merge(df_prods, on = 'order_id')

# %%
df_orders_products_merrged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11748\3661697474.py in <module>
# ----> 1 df_orders_products_merrged
#
# NameError: name 'df_orders_products_merrged' is not defined
